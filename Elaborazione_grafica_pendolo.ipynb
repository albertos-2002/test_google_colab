# %% [markdown]
# <a href="https://colab.research.google.com/github/albertos-2002/test_google_colab/blob/main/Elaborazione_grafica_pendolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import delle librerie

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Periodo singolo

# %% [markdown]
# Preparazione dei dati da graficare

# %%
#definizione asse x 
asse_x_ps = np.array(range(1,101))
#print(asse_x)

#definizione asse x_histo
x_histo_ps = np.array([1.445,1.454,1.640,1.483,1.472,1.570,1.528,1.513,1.560,1.445,1.505,1.540,1.568,1.566,1.462,1.585,1.516,1.538,1.462,1.652,1.502,1.448,1.490,1.500,1.482,1.440,1.550,1.533,1.476,1.540,1.650,1.602,1.433,1.510,1.508,1.442,1.626,1.584,1.622,1.476,1.684,1.592,1.484,1.578,1.520,1.525,1.610,1.432,1.552,1.626,1.629,1.475,1.669,1.570,1.460,1.592,1.460,1.680,1.610,1.686,1.500,1.492,1.554,1.535,1.663,1.533,1.725,1.710,1.610,1.576,1.676,1.564,1.598,1.519,1.484,1.496,1.464,1.668,1.479,1.516,1.653,1.436,1.562,1.452,1.534,1.564,1.606,1.672,1.702,1.512,1.518,1.490,1.497,1.648,1.684,1.626,1.590,1.484,1.490,1.734])
#print(x_histo)

#calcolo del numero di bin

#numero N di misure
N = 100
bin_sqrt = np.sqrt(N)
bin_sturges = 1 + np.log2(N)
bin_rice = 2 * np.power(N, 1/3)
bin_scott = 3.5 / np.power(N, 3) * 0.0935517
# -----------------------
print("sqrt")
print(bin_sqrt)
print("sturges")
print(bin_sturges)
print("rice")
print(bin_rice)
print("scott")
#abbiamo un problemino 
print(bin_scott)
# --------------------------
# Out:
# sqrt
# 10.0
# sturges
# 7.643856189774724
# rice
# 9.283177667225557
# scott
# 3.2743095e-07

# %% [markdown]
# Istogramma

# %%
plt.hist(x_histo_ps, bins=15, edgecolor="royalblue")
#plt.tick_params(width=0.034)
plt.xlabel("Misura [s]")
plt.ylabel("Frequenza")
plt.title("Misure di periodo singolo")
#plt.grid()
plt.figure(figsize=(20,15))
plt.show()

# %% [markdown]
# Andamento temporale delle misure

# %%
media_ps = 1.55168
sigma3_ps = 0.0785578*3.0
print(sigma3_ps)
meno3sigma_ps = media_ps - sigma3_ps
print(meno3sigma_ps)
piu3sigma_ps = media_ps + sigma3_ps
print(piu3sigma_ps)
# Out:
# 0.23567339999999998
# 1.3160066
# 1.7873534

# %%
plt.plot(asse_x_ps, x_histo_ps, marker=".")
plt.title("Andamento temporale delle misure di periodo singolo")
plt.ylabel("Misura [s]")
plt.xlabel("Nr. consecutivo misura")
plt.axhline(media_ps)
plt.axhline(meno3sigma_ps)
plt.axhline(piu3sigma_ps)
plt.grid()
plt.figure(figsize=(50,40))
plt.show()

# %% [markdown]
# # Periodo triplo

# %% [markdown]
# Preparazione dei dati da graficare

# %%
#definizione asse x 
asse_x_pt = np.array(range(1,101))
#print(asse_x)

#definizione asse x_histo
x_histo_pt = np.array([5.303,5.024,4.936,5.065,4.968,4.992,4.930,5.014,5.030,5.021,5.103,4.981,5.060,4.965,5.035,5.001,4.976,5.044,5.090,5.018,4.976,4.989,4.929,5.027,5.008,4.952,4.962,4.998,5.084,5.008,4.934,4.940,4.915,5.078,4.998,4.912,5.040,5.097,5.078,4.978,4.896,4.944,4.925,4.925,4.918,5.092,4.857,4.842,5.024,4.994,5.245,4.963,4.988,4.922,5.014,4.972,4.909,5.108,5.221,4.986,5.165,4.978,4.876,5.100,5.068,5.106,4.882,5.065,4.994,5.200,4.865,4.962,4.952,5.216,5.077,4.962,5.030,4.958,5.088,4.874,5.011,5.024,5.025,5.066,5.058,5.112,5.156,4.952,5.010,5.038,4.977,5.220,4.929,4.844,5.218,5.182,4.990,5.167,5.215,5.020])
#print(x_histo)

#calcolo del numero di bin

#numero N di misure
N = 100
bin_sqrt = np.sqrt(N)
bin_sturges = 1 + np.log2(N)
bin_rice = 2 * np.power(N, 1/3)
bin_scott = 3.5 / np.power(N, 3) * 0.0935517
# -----------------------
print("sqrt")
print(bin_sqrt)
print("sturges")
print(bin_sturges)
print("rice")
print(bin_rice)
print("scott")
#abbiamo un problemino 
print(bin_scott)
# --------------------------
# Out:
# sqrt
# 10.0
# sturges
# 7.643856189774724
# rice
# 9.283177667225557
# scott
# 3.2743095e-07

# %% [markdown]
# Istogramma

# %%
plt.hist(x_histo_pt, bins=11, edgecolor="royalblue")
# plt.xticks=(bins)
plt.xlabel("Misura [s]")
plt.ylabel("Frequenza")
plt.title("Misure di periodo singolo")
#plt.grid()
plt.figure(figsize=(20,15))
plt.show()

# %% [markdown]
# Andamento temporale delle misure

# %%
media_pt = 5.01836
sigma3_pt = 0.0955169*3.0
print(sigma3_pt)
meno3sigma_pt = media_pt - sigma3_pt
print(meno3sigma_pt)
piu3sigma_pt = media_pt + sigma3_pt
print(piu3sigma_pt)
# Out:
# 0.2865507
# 4.7318093
# 5.304910700000001

# %%
plt.plot(asse_x_pt, x_histo_pt, marker=".")
plt.title("Andamento temporale delle misure di periodo singolo")
plt.ylabel("Misura [s]")
plt.xlabel("Nr. consecutivo misura")
plt.axhline(media_pt)
plt.axhline(meno3sigma_pt)
plt.axhline(piu3sigma_pt)
plt.grid()
plt.figure(figsize=(50,40))
plt.show()

# %% [markdown]
# # Periodo singolo l mezzi

# %% [markdown]
# Preparazione dei dati da graficare

# %%
#definizione asse x 
asse_x_pl2 = np.array(range(1,101))
#print(asse_x)

#definizione asse x_histo
x_histo_pl2 = np.array([1.160,1.046,1.266,1.130,1.099,1.150,1.292,1.030,0.972,1.162,1.052,1.106,1.028,1.114,1.151,1.169,1.244,1.168,1.010,1.011,0.976,1.252,1.071,1.036,1.289,1.154,1.058,1.129,1.063,1.088,1.265,1.280,1.066,1.298,1.055,0.968,1.165,1.148,0.984,1.193,1.090,1.198,1.187,1.359,1.072,1.051,1.011,1.256,1.116,1.005,1.094,1.198,1.318,1.166,1.108,1.105,0.946,1.036,1.042,1.204,0.984,1.235,1.126,0.942,1.076,0.950,1.154,1.026,1.115,1.278,1.182,1.220,1.172,1.085,1.117,1.074,1.075,1.200,1.120,1.196,1.261,1.176,1.314,1.180,1.197,1.184,1.024,1.198,1.123,1.129,1.194,1.075,1.024,1.166,1.110,1.224,1.164,1.144,1.186,1.122])
#print(x_histo)

#calcolo del numero di bin

#numero N di misure
N = 100
bin_sqrt = np.sqrt(N)
bin_sturges = 1 + np.log2(N)
bin_rice = 2 * np.power(N, 1/3)
bin_scott = 3.5 / np.power(N, 3) * 0.0935517
# -----------------------
print("sqrt")
print(bin_sqrt)
print("sturges")
print(bin_sturges)
print("rice")
print(bin_rice)
print("scott")
#abbiamo un problemino 
print(bin_scott)
# --------------------------
# Out:
# sqrt
# 10.0
# sturges
# 7.643856189774724
# rice
# 9.283177667225557
# scott
# 3.2743095e-07

# %% [markdown]
# Istogramma

# %%
plt.hist(x_histo_pl2, bins=10, edgecolor="royalblue")
plt.xlabel("Misura [s]")
plt.ylabel("Frequenza")
plt.title("Misure di periodo singolo")
#plt.grid()
plt.figure(figsize=(20,15))
plt.show()

# %% [markdown]
# Andamento temporale delle misure

# %%
media_pl2 = 1.12982
sigma3_pl2 = 0.0936601*3.0
print(sigma3_pl2)
meno3sigma_pl2 = media_pl2 - sigma3_pl2
print(meno3sigma_pl2)
piu3sigma_pl2 = media_pl2 + sigma3_pl2
print(piu3sigma_pl2)
# Out:
# 0.28098029999999996
# 0.8488397000000001
# 1.4108003

# %%
plt.plot(asse_x_pl2, x_histo_pl2, marker=".")
plt.title("Andamento temporale delle misure di periodo singolo")
plt.ylabel("Misura [s]")
plt.xlabel("Nr. consecutivo misura")
plt.axhline(media_pl2)
plt.axhline(meno3sigma_pl2)
plt.axhline(piu3sigma_pl2)
plt.grid()
plt.figure(figsize=(50,40))
plt.show()
